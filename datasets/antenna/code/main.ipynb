# %%
import pandas as pd

from frictionless import Resource, Pipeline, steps

MAPPING_FILE = "mapping.csv"
DATA_CSV = "../raw-data/occurrences_preprocessed.csv"
DATA_JSON = "../raw-data/occurrences.json"

# Resource(path=DATA_CSV)

pd.read_csv(MAPPING_FILE)

steps.resource_transform
# Out:
#                                    src_field          dst_file  \
# 0                                         id  observations.csv
# 1                                   event_id  observations.csv
# 2                                        NaN  observations.csv
# 3                                        NaN  observations.csv
# 4                              deployment_id   deployments.csv
# 5                              deployment_id  observations.csv
# 6                              deployment_id         media.csv
# 7                            deployment_name               NaN
# 8                                 project_id  datapackage.json
# 9                               project_name  datapackage.json
# 10                          determination_id               NaN
# 11                        determination_name  observations.csv
# 12                       determination_score               NaN
# 13                       verification_status               NaN
# ...
